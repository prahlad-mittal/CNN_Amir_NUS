# %% [markdown]
# # Image filtering using open cv and python

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('15p22.jpg')

kernel = np.ones((5,5),np.float32)/25
print( type(kernel) )
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
def am_power(a):
    pa = 0.0 
    dim1 = a.shape
    if len(dim1)==2:
        sz = dim1[0] * dim1[1] 
        for i in range(dim1[0]):
            for j in range(dim1[1]):
                pa += a[i][j]**2
    elif len(dim1)==3:
        sz = dim1[0] * dim1[1] * dim1[2]
        for i in range(dim1[0]):
            for j in range(dim1[1]):
                for k in range(dim1[2]):
                    pa += a[i][j][k]**2
    pa = pa / sz
    return pa

# %%
print(type(img))
print(img.size)
print(img.shape)
print( am_power(img))
print( am_power(dst))
# Out:
# <class 'numpy.ndarray'>
# 138024
# (213, 216, 3)
# 19342.44928418246
# 17087.216802874864

# %%
img = cv2.imread('15p22.jpg',0)
# Output dtype = cv.CV_8U
sobelx8u = cv2.Sobel(img,cv2.CV_8U,1,0,ksize=5)
# Output dtype = cv.CV_64F. Then take its absolute and convert to cv.CV_8U
sobelx64f = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
abs_sobel64f = np.absolute(sobelx64f)
sobel_8u = np.uint8(abs_sobel64f)
plt.subplot(1,3,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(sobelx8u,cmap = 'gray')
plt.title('Sobel CV_8U'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(sobel_8u,cmap = 'gray')
plt.title('Sobel abs(CV_64F)'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.imshow(sobelx8u,cmap = 'gray')
plt.title('Sobel CV_8U'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Sobel CV_8U'), ([], []), ([], []))

# %%
plt.imshow(sobel_8u,cmap = 'gray')
plt.title('Sobel abs(CV_64F)'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Sobel abs(CV_64F)'), ([], []), ([], []))

# %%
print(am_power(sobelx8u))
print(am_power(sobel_8u))
# Out:
# 22073.807946444096
# 17882.054229699184

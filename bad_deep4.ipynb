# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import os

num_skipped = 0
for folder_name in ("Cat", "Dog"):
    folder_path = os.path.join("PetImages", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print("Deleted %d images" % num_skipped)
# Out:
# Deleted 0 images

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ---------
# absl-py                            0.10.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# asn1crypto                         1.0.1
# astor                              0.8.1
# astroid                            2.3.1
# astropy                            3.2.1
# atomicwrites                       1.3.0
# attrs                              19.2.0
# Babel                              2.7.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.5
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.8.0
# bitarray                           1.0.1
# bkcharts                           0.2
# bleach                             3.1.0
# bokeh                              1.3.4
# boto                               2.49.0
# Bottleneck                         1.2.1
# cachetools                         3.1.1
# certifi                            2019.9.11
# cffi                               1.12.3
# chardet                            3.0.4
# Click                              7.0
# cloudpickle                        1.2.2
# clyent                             1.2.2
# colorama                           0.4.1
# comtypes                           1.1.7
# conda                              4.8.4
# conda-build                        3.18.9
# conda-package-handling             1.6.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0
# cryptography                       2.7
# cycler                             0.10.0
# Cython                             0.29.13
# cytoolz                            0.10.0
# dask                               2.5.2
# decorator                          4.4.0
# defusedxml                         0.6.0
# distributed                        2.5.2
# docutils                           0.15.2
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# Flask                              1.1.1
# fsspec                             0.5.2
# future                             0.17.1
# gast                               0.4.0
# gevent                             1.4.0
# glob2                              0.7
# google-auth                        1.6.3
# google-auth-oauthlib               0.4.1
# google-pasta                       0.2.0
# greenlet                           0.4.15
# grpcio                             1.24.3
# h5py                               2.9.0
# HeapDict                           1.0.1
# html5lib                           1.0.1
# idna                               2.8
# imageio                            2.6.0
# imagesize                          1.1.0
# importlib-metadata                 1.7.0
# ipykernel                          5.1.2
# ipython                            7.8.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              4.3.21
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.15.1
# Jinja2                             2.10.3
# joblib                             0.13.2
# json5                              0.8.5
# jsonschema                         3.0.2
# jupyter                            1.0.0
# jupyter-client                     5.3.3
# jupyter-console                    6.0.0
# jupyter-core                       4.5.0
# jupyterlab                         1.1.4
# jupyterlab-server                  1.0.6
# kanren                             0.2.3
# Keras                              2.3.1
# Keras-Applications                 1.0.8
# Keras-Preprocessing                1.1.0
# keyring                            18.0.0
# kiwisolver                         1.1.0
# lazy-object-proxy                  1.4.2
# libarchive-c                       2.8
# llvmlite                           0.29.0
# locket                             0.2.0
# lxml                               4.4.1
# Mako                               1.1.3
# Markdown                           3.2.2
# MarkupSafe                         1.1.1
# matplotlib                         3.1.1
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.0.14
# mkl-random                         1.1.0
# mkl-service                        2.3.0
# mock                               3.0.5
# more-itertools                     7.2.0
# mpmath                             1.1.0
# msgpack                            0.6.1
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbconvert                          5.6.0
# nbformat                           4.4.0
# networkx                           2.3
# nltk                               3.4.5
# nose                               1.3.7
# notebook                           6.0.1
# numba                              0.45.1
# numexpr                            2.7.0
# numpy                              1.16.5
# numpydoc                           0.9.1
# oauthlib                           3.1.0
# olefile                            0.46
# openpyxl                           3.0.0
# opt-einsum                         3.1.0
# packaging                          19.2
# pandas                             0.25.1
# pandocfilters                      1.4.2
# parso                              0.5.1
# partd                              1.0.0
# path.py                            12.0.1
# pathlib2                           2.3.5
# patsy                              0.5.1
# pep8                               1.7.1
# pickleshare                        0.7.5
# Pillow                             6.2.0
# pip                                19.2.3
# pkginfo                            1.5.0.1
# pluggy                             0.13.0
# ply                                3.11
# prometheus-client                  0.7.1
# prompt-toolkit                     2.0.10
# protobuf                           3.13.0
# psutil                             5.6.3
# py                                 1.8.0
# pyasn1                             0.4.7
# pyasn1-modules                     0.2.7
# pycodestyle                        2.5.0
# pycosat                            0.6.3
# pycparser                          2.19
# pycrypto                           2.6.1
# pycurl                             7.43.0.3
# pyflakes                           2.1.1
# Pygments                           2.4.2
# pygpu                              0.7.6
# pylint                             2.4.2
# pyodbc                             4.0.27
# pyOpenSSL                          19.0.0
# pyparsing                          2.4.2
# pyreadline                         2.1
# pyrsistent                         0.15.4
# PySocks                            1.7.1
# pytest                             5.2.1
# pytest-arraydiff                   0.3
# pytest-astropy                     0.5.0
# pytest-doctestplus                 0.4.0
# pytest-openfiles                   0.4.0
# pytest-remotedata                  0.3.2
# python-dateutil                    2.8.0
# pytz                               2019.3
# PyWavelets                         1.0.3
# pywin32                            223
# pywinpty                           0.5.5
# PyYAML                             5.1.2
# pyzmq                              18.1.0
# QtAwesome                          0.6.0
# qtconsole                          4.5.5
# QtPy                               1.9.0
# requests                           2.22.0
# requests-oauthlib                  1.2.0
# rope                               0.14.0
# rsa                                4.0
# ruamel-yaml                        0.15.46
# scikit-image                       0.15.0
# scikit-learn                       0.21.3
# scipy                              1.3.1
# seaborn                            0.9.0
# Send2Trash                         1.5.0
# setuptools                         41.4.0
# simplegeneric                      0.8.1
# SimpSOM                            1.3.4
# singledispatch                     3.4.0.3
# six                                1.12.0
# sklearn                            0.0
# snowballstemmer                    2.0.0
# sortedcollections                  1.1.2
# sortedcontainers                   2.1.0
# soupsieve                          1.9.3
# Sphinx                             2.2.0
# sphinxcontrib-applehelp            1.0.1
# sphinxcontrib-devhelp              1.0.1
# sphinxcontrib-htmlhelp             1.0.2
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.2
# sphinxcontrib-serializinghtml      1.1.3
# sphinxcontrib-websupport           1.1.2
# spyder                             3.3.6
# spyder-kernels                     0.5.2
# SQLAlchemy                         1.3.9
# statsmodels                        0.10.1
# sympy                              1.4
# tables                             3.5.2
# tblib                              1.4.0
# tensorboard                        2.0.1
# tensorflow                         2.0.0
# tensorflow-estimator               2.0.1
# termcolor                          1.1.0
# terminado                          0.8.2
# testpath                           0.4.2
# Theano                             1.0.5
# toolz                              0.10.0
# tornado                            6.0.3
# tqdm                               4.36.1
# traitlets                          4.3.3
# unicodecsv                         0.14.1
# unification                        0.2.2
# urllib3                            1.24.2
# wcwidth                            0.1.7
# webencodings                       0.5.1
# Werkzeug                           0.16.0
# wheel                              0.33.6
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.11.2
# xlrd                               1.2.0
# XlsxWriter                         1.2.1
# xlwings                            0.15.10
# xlwt                               1.3.0
# zict                               1.0.0
# zipp                               0.6.0

# %%
# !pip list --outdated
# Out:
# Package                       Version   Latest      Type
# ----------------------------- --------- ----------- -----
# absl-py                       0.10.0    0.11.0      wheel
# asn1crypto                    1.0.1     1.4.0       wheel
# astroid                       2.3.1     2.4.2       wheel
# astropy                       3.2.1     4.2         wheel
# atomicwrites                  1.3.0     1.4.0       wheel
# attrs                         19.2.0    20.3.0      wheel
# Babel                         2.7.0     2.9.0       wheel
# backcall                      0.1.0     0.2.0       wheel
# backports.functools-lru-cache 1.5       1.6.1       wheel
# beautifulsoup4                4.8.0     4.9.3       wheel
# bitarray                      1.0.1     1.6.1       sdist
# bleach                        3.1.0     3.2.1       wheel
# bokeh                         1.3.4     2.2.3       sdist
# Bottleneck                    1.2.1     1.3.2       sdist
# cachetools                    3.1.1     4.1.1       wheel
# certifi                       2019.9.11 2020.11.8   wheel
# cffi                          1.12.3    1.14.4      wheel
# Click                         7.0       7.1.2       wheel
# cloudpickle                   1.2.2     1.6.0       wheel
# colorama                      0.4.1     0.4.4       wheel
# contextlib2                   0.6.0     0.6.0.post1 wheel
# cryptography                  2.7       3.2.1       wheel
# Cython                        0.29.13   0.29.21     wheel
# cytoolz                       0.10.0    0.11.0      sdist
# dask                          2.5.2     2.30.0      wheel
# decorator                     4.4.0     4.4.2       wheel
# distributed                   2.5.2     2.30.1      wheel
# docutils                      0.15.2    0.16        wheel
# Flask                         1.1.1     1.1.2       wheel
# fsspec                        0.5.2     0.8.4       wheel
# future                        0.17.1    0.18.2      sdist
# gevent                        1.4.0     20.9.0      wheel
# google-auth                   1.6.3     1.23.0      wheel
# google-auth-oauthlib          0.4.1     0.4.2       wheel
# greenlet                      0.4.15    0.4.17      wheel
# grpcio                        1.24.3    1.34.0      wheel
# h5py                          2.9.0     3.1.0       wheel
# html5lib                      1.0.1     1.1         wheel
# idna                          2.8       2.10        wheel
# imageio                       2.6.0     2.9.0       wheel
# imagesize                     1.1.0     1.2.0       wheel
# importlib-metadata            1.7.0     3.1.1       wheel
# ipykernel                     5.1.2     5.3.4       wheel
# ipython                       7.8.0     7.19.0      wheel
# isort                         4.3.21    5.6.4       wheel
# jedi                          0.15.1    0.17.2      wheel
# Jinja2                        2.10.3    2.11.2      wheel
# joblib                        0.13.2    0.17.0      wheel
# json5                         0.8.5     0.9.5       wheel
# jsonschema                    3.0.2     3.2.0       wheel
# jupyter-client                5.3.3     6.1.7       wheel
# jupyter-console               6.0.0     6.2.0       wheel
# jupyter-core                  4.5.0     4.7.0       wheel
# jupyterlab                    1.1.4     2.2.9       wheel
# jupyterlab-server             1.0.6     1.2.0       wheel
# Keras                         2.3.1     2.4.3       wheel
# Keras-Preprocessing           1.1.0     1.1.2       wheel
# keyring                       18.0.0    21.5.0      wheel
# kiwisolver                    1.1.0     1.3.1       wheel
# lazy-object-proxy             1.4.2     1.5.2       wheel
# libarchive-c                  2.8       2.9         wheel
# llvmlite                      0.29.0    0.35.0      wheel
# lxml                          4.4.1     4.6.2       wheel
# Markdown                      3.2.2     3.3.3       wheel
# matplotlib                    3.1.1     3.3.3       wheel
# mock                          3.0.5     4.0.2       wheel
# more-itertools                7.2.0     8.6.0       wheel
# msgpack                       0.6.1     1.0.0       wheel
# nbconvert                     5.6.0     6.0.7       wheel
# nbformat                      4.4.0     5.0.8       wheel
# networkx                      2.3       2.5         wheel
# nltk                          3.4.5     3.5         sdist
# notebook                      6.0.1     6.1.5       wheel
# numba                         0.45.1    0.52.0      wheel
# numexpr                       2.7.0     2.7.1       wheel
# numpy                         1.16.5    1.19.4      wheel
# numpydoc                      0.9.1     1.1.0       wheel
# openpyxl                      3.0.0     3.0.5       wheel
# opt-einsum                    3.1.0     3.3.0       wheel
# packaging                     19.2      20.7        wheel
# pandas                        0.25.1    1.1.4       wheel
# pandocfilters                 1.4.2     1.4.3       sdist
# parso                         0.5.1     0.8.0       wheel
# partd                         1.0.0     1.1.0       wheel
# path.py                       12.0.1    12.5.0      wheel
# Pillow                        6.2.0     8.0.1       wheel
# pip                           19.2.3    20.3        wheel
# pkginfo                       1.5.0.1   1.6.1       wheel
# pluggy                        0.13.0    0.13.1      wheel
# prometheus-client             0.7.1     0.9.0       wheel
# prompt-toolkit                2.0.10    3.0.8       wheel
# protobuf                      3.13.0    3.14.0      wheel
# psutil                        5.6.3     5.7.3       wheel
# py                            1.8.0     1.9.0       wheel
# pyasn1                        0.4.7     0.4.8       wheel
# pyasn1-modules                0.2.7     0.2.8       wheel
# pycodestyle                   2.5.0     2.6.0       wheel
# pycparser                     2.19      2.20        wheel
# pycurl                        7.43.0.3  7.43.0.6    sdist
# pyflakes                      2.1.1     2.2.0       wheel
# Pygments                      2.4.2     2.7.2       wheel
# pylint                        2.4.2     2.6.0       wheel
# pyodbc                        4.0.27    4.0.30      wheel
# pyOpenSSL                     19.0.0    20.0.0      wheel
# pyparsing                     2.4.2     2.4.7       wheel
# pyrsistent                    0.15.4    0.17.3      sdist
# pytest                        5.2.1     6.1.2       wheel
# pytest-astropy                0.5.0     0.8.0       wheel
# pytest-doctestplus            0.4.0     0.8.0       sdist
# pytest-openfiles              0.4.0     0.5.0       wheel
# python-dateutil               2.8.0     2.8.1       wheel
# pytz                          2019.3    2020.4      wheel
# PyWavelets                    1.0.3     1.1.1       wheel
# pywin32                       223       300         wheel
# pywinpty                      0.5.5     0.5.7       wheel
# PyYAML                        5.1.2     5.3.1       wheel
# pyzmq                         18.1.0    20.0.0      wheel
# QtAwesome                     0.6.0     1.0.1       wheel
# qtconsole                     4.5.5     5.0.1       wheel
# requests                      2.22.0    2.25.0      wheel
# requests-oauthlib             1.2.0     1.3.0       wheel
# rope                          0.14.0    0.18.0      sdist
# rsa                           4.0       4.6         wheel
# ruamel-yaml                   0.15.46   0.16.12     wheel
# scikit-image                  0.15.0    0.17.2      wheel
# scikit-learn                  0.21.3    0.23.2      wheel
# scipy                         1.3.1     1.5.4       wheel
# seaborn                       0.9.0     0.11.0      wheel
# setuptools                    41.4.0    50.3.2      wheel
# six                           1.12.0    1.15.0      wheel
# sortedcollections             1.1.2     1.2.1       wheel
# sortedcontainers              2.1.0     2.3.0       wheel
# soupsieve                     1.9.3     2.0.1       wheel
# Sphinx                        2.2.0     3.3.1       wheel
# sphinxcontrib-applehelp       1.0.1     1.0.2       wheel
# sphinxcontrib-devhelp         1.0.1     1.0.2       wheel
# sphinxcontrib-htmlhelp        1.0.2     1.0.3       wheel
# sphinxcontrib-qthelp          1.0.2     1.0.3       wheel
# sphinxcontrib-serializinghtml 1.1.3     1.1.4       wheel
# sphinxcontrib-websupport      1.1.2     1.2.4       wheel
# spyder                        3.3.6     4.2.0       wheel
# spyder-kernels                0.5.2     1.10.0      wheel
# SQLAlchemy                    1.3.9     1.3.20      wheel
# statsmodels                   0.10.1    0.12.1      wheel
# sympy                         1.4       1.7         wheel
# tables                        3.5.2     3.6.1       wheel
# tblib                         1.4.0     1.7.0       wheel
# tensorboard                   2.0.1     2.4.0       wheel
# tensorflow                    2.0.0     2.3.1       wheel
# tensorflow-estimator          2.0.1     2.3.0       wheel
# terminado                     0.8.2     0.9.1       wheel
# testpath                      0.4.2     0.4.4       wheel
# toolz                         0.10.0    0.11.1      wheel
# tornado                       6.0.3     6.1         wheel
# tqdm                          4.36.1    4.54.0      wheel
# traitlets                     4.3.3     5.0.5       wheel
# urllib3                       1.24.2    1.26.2      wheel
# wcwidth                       0.1.7     0.2.5       wheel
# Werkzeug                      0.16.0    1.0.1       wheel
# wheel                         0.33.6    0.36.0      wheel
# wrapt                         1.11.2    1.12.1      sdist
# XlsxWriter                    1.2.1     1.3.7       wheel
# xlwings                       0.15.10   0.21.4      sdist
# zict                          1.0.0     2.0.0       wheel
# zipp                          0.6.0     3.4.0       wheel

# %%
# !pip install tensorflow --upgrade
# Out:
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/5d/6a/9669836f813b73fe5abf5e9f118ccc9b7fb060f02789d385825b0943f9c8/tensorflow-2.3.1-cp37-cp37m-win_amd64.whl (342.5MB)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/e9/ed/5853ec0ae380cba4588eab1524e18ece1583b65f7ae0e97321f5ff9dfd60/tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459kB)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.10.0)
# Requirement already satisfied, skipping upgrade: numpy<1.19.0,>=1.16.0 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.16.5)
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Collecting tensorboard<3,>=2.3.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/02/83/179c8f76e5716030cc3ee9433721161cfcc1d854e9ba20c9205180bb100a/tensorboard-2.4.0-py3-none-any.whl (10.6MB)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.12.0)
# Collecting astunparse==1.6.3 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl
# Collecting h5py<2.11.0,>=2.10.0 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/a1/6b/7f62017e3f0b32438dd90bdc1ff0b7b1448b6cb04a1ed84f37b6de95cd7b/h5py-2.10.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.24.3)
# Collecting gast==0.3.3 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/d6/84/759f5dd23fec8ba71952d97bcc7e2c9d7d63bdc582421f3cd4be845f0c98/gast-0.3.3-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.33.6)
# Collecting keras-preprocessing<1.2,>=1.1.1 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42kB)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from protobuf>=3.9.2->tensorflow) (41.4.0)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<3,>=2.3.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/b6/85/5c5ac0a8c5efdfab916e9c6bc18963f6a6996a8a1e19ec4ad8c9ac9c623c/tensorboard_plugin_wit-1.7.0-py3-none-any.whl (779kB)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.2.2)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.22.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.16.0)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.6.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2019.9.11)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.24.2)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.2.0)
# Requirement already satisfied, skipping upgrade: cachetools>=2.0.0 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.7)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (0.6.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.7)
# Requirement already satisfied, skipping upgrade: more-itertools in c:\users\sleam\appdata\local\continuum\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (7.2.0)
# Installing collected packages: tensorflow-estimator, tensorboard-plugin-wit, tensorboard, astunparse, h5py, gast, keras-preprocessing, tensorflow
#   Found existing installation: tensorflow-estimator 2.0.1
#     Uninstalling tensorflow-estimator-2.0.1:
#       Successfully uninstalled tensorflow-estimator-2.0.1
#   Found existing installation: tensorboard 2.0.1
#     Uninstalling tensorboard-2.0.1:
#       Successfully uninstalled tensorboard-2.0.1
#   Found existing installation: h5py 2.9.0
#     Uninstalling h5py-2.9.0:
#       Successfully uninstalled h5py-2.9.0
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\users\\sleam\\appdata\\local\\continuum\\anaconda3\\lib\\site-packages\\~5py\\defs.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

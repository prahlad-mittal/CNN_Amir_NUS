# %%
# Output Images 
plt.imshow(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = 255 - img

# %%
plt.imshow(img)

# %%
 img.shape
# Out:
# (565, 800, 3)

# %%
img = 255-img
plt.imshow(img)

# %%
z=len(img)
img.shape
# Out:
# (565, 800, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.max(), img.min()
# Out:
# (255, 0)

# %%
rotate = ndimage.rotate(img, 45)

# %%
plt.imshow(rotate)

# %%
blurred = ndimage.gaussian_filter(img, sigma=3)
very_blurred = ndimage.gaussian_filter(img, sigma=5)

# %%
plt.imshow(blurred)

# %%
plt.imshow(very_blurred)

# %%
blurred.shape
# Out:
# (565, 800, 3)

# %%
unshrpmsk1 = img[:,:,1] - blurred[:,:,1] 
plt.imshow(unshrpmsk1)

# %%
unshrpmsk2 = img[:,:,1] - very_blurred[:,:,1] 
plt.imshow(unshrpmsk2)

# %%
img2 = mpimg.imread("monty-python-and-the-holy-grail_pan_17302.jpg")

# %%
# Output Images 
plt.imshow(img2)

# %%
#img2 = img2 - img2.min()
img2 = img2 / 4 + 35
img2 = uint8(img2) 
plt.imshow(img2)

# %%
img2.max()
# Out:
# 98
